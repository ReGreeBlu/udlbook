# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.306128, train error 89.45,  test loss 2.305416, test error 89.85
# Epoch   100, train loss 1.922123, train error 71.82,  test loss 1.783247, test error 69.65
# Epoch   200, train loss 1.912398, train error 71.82,  test loss 1.763488, test error 70.55
# Epoch   300, train loss 1.904220, train error 71.68,  test loss 1.737315, test error 69.07
# Epoch   400, train loss 1.901255, train error 71.53,  test loss 1.738020, test error 69.65
# Epoch   500, train loss 1.898898, train error 70.82,  test loss 1.742219, test error 68.68
# Epoch   600, train loss 1.899256, train error 71.50,  test loss 1.743777, test error 69.32
# Epoch   700, train loss 1.897752, train error 71.62,  test loss 1.742374, test error 68.93
# Epoch   800, train loss 1.897139, train error 70.68,  test loss 1.743685, test error 68.65
# Epoch   900, train loss 1.918279, train error 72.93,  test loss 1.784920, test error 71.85
# Training model with   4 hidden variables
# Epoch     0, train loss 2.204081, train error 82.97,  test loss 2.181488, test error 81.85
# Epoch   100, train loss 1.834816, train error 69.68,  test loss 1.700140, test error 68.62
# Epoch   200, train loss 1.818270, train error 68.15,  test loss 1.702698, test error 66.80
# Epoch   300, train loss 1.806023, train error 67.25,  test loss 1.682624, test error 65.70
# Epoch   400, train loss 1.798429, train error 67.00,  test loss 1.673966, test error 65.45
# Epoch   500, train loss 1.795243, train error 66.78,  test loss 1.669729, test error 65.22
# Epoch   600, train loss 1.787394, train error 66.28,  test loss 1.672728, test error 65.43
# Epoch   700, train loss 1.783280, train error 66.40,  test loss 1.659757, test error 65.18
# Epoch   800, train loss 1.781719, train error 66.45,  test loss 1.670544, test error 65.97
# Epoch   900, train loss 1.780867, train error 66.82,  test loss 1.669940, test error 65.57
# Training model with   6 hidden variables
# Epoch     0, train loss 2.158080, train error 80.22,  test loss 2.114243, test error 78.22
# Epoch   100, train loss 1.712742, train error 61.97,  test loss 1.514417, test error 58.30
# Epoch   200, train loss 1.659653, train error 59.72,  test loss 1.487402, test error 57.10
# Epoch   300, train loss 1.636793, train error 59.70,  test loss 1.466870, test error 55.97
# Epoch   400, train loss 1.622969, train error 58.97,  test loss 1.471939, test error 56.08
# Epoch   500, train loss 1.615800, train error 58.50,  test loss 1.474478, test error 56.33
# Epoch   600, train loss 1.609791, train error 58.12,  test loss 1.468487, test error 55.70
# Epoch   700, train loss 1.609285, train error 57.45,  test loss 1.469757, test error 55.85
# Epoch   800, train loss 1.611812, train error 57.75,  test loss 1.478705, test error 55.80
# Epoch   900, train loss 1.604652, train error 57.72,  test loss 1.459459, test error 55.25
# Training model with   8 hidden variables
# Epoch     0, train loss 2.139320, train error 77.35,  test loss 2.098913, test error 76.82
# Epoch   100, train loss 1.594026, train error 55.62,  test loss 1.419401, test error 53.90
# Epoch   200, train loss 1.546852, train error 53.75,  test loss 1.403491, test error 53.33
# Epoch   300, train loss 1.527208, train error 53.58,  test loss 1.405421, test error 53.55
# Epoch   400, train loss 1.522030, train error 53.78,  test loss 1.412658, test error 53.38
# Epoch   500, train loss 1.513768, train error 53.05,  test loss 1.412694, test error 54.22
# Epoch   600, train loss 1.516810, train error 53.30,  test loss 1.415602, test error 53.22
# Epoch   700, train loss 1.512049, train error 52.85,  test loss 1.424832, test error 54.22
# Epoch   800, train loss 1.510459, train error 53.05,  test loss 1.434096, test error 54.35
# Epoch   900, train loss 1.512855, train error 52.90,  test loss 1.443086, test error 54.15
# Training model with  10 hidden variables
# Epoch     0, train loss 2.259573, train error 85.20,  test loss 2.243629, test error 84.57
# Epoch   100, train loss 1.488283, train error 50.00,  test loss 1.312679, test error 48.30
# Epoch   200, train loss 1.435647, train error 48.20,  test loss 1.271972, test error 47.00
# Epoch   300, train loss 1.411437, train error 47.22,  test loss 1.279669, test error 47.45
# Epoch   400, train loss 1.405106, train error 46.38,  test loss 1.294048, test error 47.60
# Epoch   500, train loss 1.399478, train error 46.33,  test loss 1.305226, test error 47.67
# Epoch   600, train loss 1.395764, train error 46.62,  test loss 1.305280, test error 47.90
# Epoch   700, train loss 1.394983, train error 46.58,  test loss 1.315194, test error 48.20
# Epoch   800, train loss 1.389407, train error 46.55,  test loss 1.317946, test error 49.08
# Epoch   900, train loss 1.385330, train error 46.90,  test loss 1.320853, test error 48.72
# Training model with  14 hidden variables
# Epoch     0, train loss 2.248548, train error 83.55,  test loss 2.245918, test error 83.85
# Epoch   100, train loss 1.408136, train error 47.38,  test loss 1.297693, test error 49.20
# Epoch   200, train loss 1.303152, train error 42.50,  test loss 1.277929, test error 47.85
# Epoch   300, train loss 1.266571, train error 41.62,  test loss 1.299996, test error 47.28
# Epoch   400, train loss 1.258221, train error 41.30,  test loss 1.306575, test error 47.42
# Epoch   500, train loss 1.248204, train error 40.85,  test loss 1.335322, test error 47.90
# Epoch   600, train loss 1.240778, train error 41.20,  test loss 1.353461, test error 47.83
# Epoch   700, train loss 1.234191, train error 40.55,  test loss 1.358686, test error 47.12
# Epoch   800, train loss 1.233900, train error 40.15,  test loss 1.366783, test error 47.42
# Epoch   900, train loss 1.226803, train error 40.45,  test loss 1.381016, test error 47.25
# Training model with  18 hidden variables
# Epoch     0, train loss 2.182972, train error 80.45,  test loss 2.150555, test error 79.30
# Epoch   100, train loss 1.354422, train error 44.22,  test loss 1.336476, test error 51.12
# Epoch   200, train loss 1.298463, train error 42.78,  test loss 1.381901, test error 52.05
# Epoch   300, train loss 1.238821, train error 41.70,  test loss 1.394720, test error 51.72
# Epoch   400, train loss 1.215715, train error 40.38,  test loss 1.456418, test error 52.83
# Epoch   500, train loss 1.210531, train error 41.33,  test loss 1.496055, test error 53.08
# Epoch   600, train loss 1.184819, train error 40.22,  test loss 1.525977, test error 53.47
# Epoch   700, train loss 1.183386, train error 40.28,  test loss 1.548150, test error 54.08
# Epoch   800, train loss 1.180872, train error 41.08,  test loss 1.574885, test error 54.03
# Epoch   900, train loss 1.178747, train error 41.28,  test loss 1.604366, test error 54.67
# Training model with  22 hidden variables
# Epoch     0, train loss 2.136453, train error 80.85,  test loss 2.097129, test error 80.32
# Epoch   100, train loss 1.262899, train error 41.33,  test loss 1.327798, test error 49.28
# Epoch   200, train loss 1.157940, train error 38.90,  test loss 1.391571, test error 50.05
# Epoch   300, train loss 1.109214, train error 36.67,  test loss 1.454485, test error 50.47
# Epoch   400, train loss 1.073022, train error 35.25,  test loss 1.511122, test error 51.22
# Epoch   500, train loss 1.056524, train error 34.47,  test loss 1.582600, test error 52.65
# Epoch   600, train loss 1.040982, train error 34.47,  test loss 1.629864, test error 52.33
# Epoch   700, train loss 1.032687, train error 35.10,  test loss 1.674567, test error 52.70
# Epoch   800, train loss 1.008526, train error 34.65,  test loss 1.702419, test error 52.83
# Epoch   900, train loss 1.002672, train error 33.72,  test loss 1.739826, test error 52.90
# Training model with  26 hidden variables
# Epoch     0, train loss 2.169201, train error 80.18,  test loss 2.146174, test error 80.55
# Epoch   100, train loss 1.208841, train error 39.83,  test loss 1.302845, test error 48.50
# Epoch   200, train loss 1.066427, train error 35.95,  test loss 1.418137, test error 50.25
# Epoch   300, train loss 1.000523, train error 33.45,  test loss 1.549312, test error 51.53
# Epoch   400, train loss 0.963600, train error 32.03,  test loss 1.660250, test error 52.62
# Epoch   500, train loss 0.930909, train error 31.25,  test loss 1.730001, test error 51.83
# Epoch   600, train loss 0.911955, train error 30.12,  test loss 1.818348, test error 52.38
# Epoch   700, train loss 0.882282, train error 29.78,  test loss 1.890735, test error 53.62
# Epoch   800, train loss 0.873263, train error 29.93,  test loss 1.946909, test error 53.47
# Epoch   900, train loss 0.870313, train error 29.82,  test loss 2.019419, test error 53.97
# Training model with  30 hidden variables
# Epoch     0, train loss 2.098588, train error 79.68,  test loss 2.034710, test error 79.47
# Epoch   100, train loss 1.106094, train error 35.65,  test loss 1.302084, test error 47.55
# Epoch   200, train loss 0.953221, train error 31.18,  test loss 1.464350, test error 49.60
# Epoch   300, train loss 0.849955, train error 27.78,  test loss 1.630282, test error 49.53
# Epoch   400, train loss 0.792041, train error 26.03,  test loss 1.786457, test error 51.03
# Epoch   500, train loss 0.752028, train error 24.68,  test loss 1.948538, test error 52.12
# Epoch   600, train loss 0.730440, train error 24.62,  test loss 2.096014, test error 51.65
# Epoch   700, train loss 0.719481, train error 24.80,  test loss 2.214626, test error 52.33
# Epoch   800, train loss 0.691746, train error 23.82,  test loss 2.297251, test error 52.90
# Epoch   900, train loss 0.660647, train error 22.38,  test loss 2.416838, test error 53.25
# Training model with  35 hidden variables
# Epoch     0, train loss 2.095827, train error 77.53,  test loss 2.052592, test error 77.18
# Epoch   100, train loss 0.993197, train error 32.35,  test loss 1.360189, test error 49.03
# Epoch   200, train loss 0.795647, train error 25.93,  test loss 1.663071, test error 52.08
# Epoch   300, train loss 0.680991, train error 22.35,  test loss 2.013947, test error 53.95
# Epoch   400, train loss 0.595988, train error 20.28,  test loss 2.450176, test error 54.58
# Epoch   500, train loss 0.531081, train error 17.68,  test loss 2.724342, test error 55.05
# Epoch   600, train loss 0.532499, train error 18.38,  test loss 3.131268, test error 56.62
# Epoch   700, train loss 0.476448, train error 16.70,  test loss 3.371904, test error 55.38
# Epoch   800, train loss 0.442703, train error 14.97,  test loss 3.642989, test error 56.40
# Epoch   900, train loss 0.431486, train error 14.40,  test loss 3.940489, test error 56.15
# Training model with  40 hidden variables
# Epoch     0, train loss 2.124261, train error 79.10,  test loss 2.094078, test error 78.62
# Epoch   100, train loss 0.914458, train error 29.85,  test loss 1.555222, test error 52.22
# Epoch   200, train loss 0.656391, train error 21.70,  test loss 2.023211, test error 54.38
# Epoch   300, train loss 0.546690, train error 18.28,  test loss 2.621570, test error 55.55
# Epoch   400, train loss 0.455691, train error 15.50,  test loss 3.236129, test error 56.62
# Epoch   500, train loss 0.423810, train error 14.22,  test loss 3.797244, test error 55.78
# Epoch   600, train loss 0.351668, train error 11.60,  test loss 4.442909, test error 56.75
# Epoch   700, train loss 0.348794, train error 12.12,  test loss 5.018482, test error 57.65
# Epoch   800, train loss 0.326452, train error 11.45,  test loss 5.555653, test error 56.80
# Epoch   900, train loss 0.347183, train error 12.53,  test loss 6.201270, test error 57.58
# Training model with  45 hidden variables
# Epoch     0, train loss 2.092137, train error 77.62,  test loss 2.041591, test error 77.12
# Epoch   100, train loss 0.812217, train error 25.72,  test loss 1.431613, test error 48.03
# Epoch   200, train loss 0.507920, train error 15.95,  test loss 2.110372, test error 53.75
# Epoch   300, train loss 0.312825, train error 9.22,  test loss 3.081306, test error 55.58
# Epoch   400, train loss 0.226493, train error 7.15,  test loss 4.051545, test error 55.42
# Epoch   500, train loss 0.186335, train error 6.78,  test loss 5.209679, test error 56.17
# Epoch   600, train loss 0.141126, train error 4.20,  test loss 6.310469, test error 55.65
# Epoch   700, train loss 0.135542, train error 4.20,  test loss 7.281981, test error 55.95
# Epoch   800, train loss 0.011981, train error 0.00,  test loss 8.265678, test error 56.00
# Epoch   900, train loss 0.007088, train error 0.00,  test loss 8.929024, test error 56.33
# Training model with  50 hidden variables
# Epoch     0, train loss 2.062171, train error 76.93,  test loss 2.023705, test error 76.82
# Epoch   100, train loss 0.708321, train error 22.22,  test loss 1.607527, test error 50.33
# Epoch   200, train loss 0.323037, train error 9.68,  test loss 2.716998, test error 54.10
# Epoch   300, train loss 0.135068, train error 3.10,  test loss 4.343799, test error 55.17
# Epoch   400, train loss 0.024058, train error 0.00,  test loss 5.908269, test error 55.85
# Epoch   500, train loss 0.011984, train error 0.00,  test loss 6.794968, test error 55.67
# Epoch   600, train loss 0.007905, train error 0.00,  test loss 7.392518, test error 56.12
# Epoch   700, train loss 0.005709, train error 0.00,  test loss 7.849180, test error 55.67
# Epoch   800, train loss 0.004422, train error 0.00,  test loss 8.225248, test error 55.83
# Epoch   900, train loss 0.003565, train error 0.00,  test loss 8.526696, test error 55.90
# Training model with  55 hidden variables
# Epoch     0, train loss 2.129660, train error 78.05,  test loss 2.094221, test error 78.65
# Epoch   100, train loss 0.679589, train error 21.28,  test loss 1.646688, test error 50.00
# Epoch   200, train loss 0.256837, train error 7.38,  test loss 2.920217, test error 54.55
# Epoch   300, train loss 0.073891, train error 0.72,  test loss 4.635282, test error 55.33
# Epoch   400, train loss 0.016241, train error 0.00,  test loss 5.911012, test error 55.83
# Epoch   500, train loss 0.009225, train error 0.00,  test loss 6.634285, test error 55.95
# Epoch   600, train loss 0.006181, train error 0.00,  test loss 7.115234, test error 55.97
# Epoch   700, train loss 0.004570, train error 0.00,  test loss 7.502398, test error 56.08
# Epoch   800, train loss 0.003592, train error 0.00,  test loss 7.811310, test error 55.85
# Epoch   900, train loss 0.002950, train error 0.00,  test loss 8.070152, test error 56.03
# Training model with  60 hidden variables
# Epoch     0, train loss 2.056527, train error 77.65,  test loss 2.011583, test error 77.40
# Epoch   100, train loss 0.537257, train error 15.70,  test loss 1.706207, test error 50.97
# Epoch   200, train loss 0.103289, train error 0.95,  test loss 3.306778, test error 54.30
# Epoch   300, train loss 0.019262, train error 0.00,  test loss 4.555687, test error 54.40
# Epoch   400, train loss 0.009307, train error 0.00,  test loss 5.201585, test error 54.47
# Epoch   500, train loss 0.005904, train error 0.00,  test loss 5.635627, test error 54.67
# Epoch   600, train loss 0.004248, train error 0.00,  test loss 5.953334, test error 54.85
# Epoch   700, train loss 0.003253, train error 0.00,  test loss 6.204420, test error 54.60
# Epoch   800, train loss 0.002613, train error 0.00,  test loss 6.412450, test error 54.75
# Epoch   900, train loss 0.002175, train error 0.00,  test loss 6.593632, test error 54.70
# Training model with  70 hidden variables
# Epoch     0, train loss 2.056506, train error 76.30,  test loss 2.006823, test error 76.12
# Epoch   100, train loss 0.396706, train error 10.97,  test loss 2.023414, test error 53.28
# Epoch   200, train loss 0.032212, train error 0.00,  test loss 3.767753, test error 56.25
# Epoch   300, train loss 0.010836, train error 0.00,  test loss 4.593305, test error 56.28
# Epoch   400, train loss 0.005988, train error 0.00,  test loss 5.057229, test error 56.35
# Epoch   500, train loss 0.004032, train error 0.00,  test loss 5.377185, test error 56.17
# Epoch   600, train loss 0.002985, train error 0.00,  test loss 5.623980, test error 56.20
# Epoch   700, train loss 0.002355, train error 0.00,  test loss 5.823829, test error 56.12
# Epoch   800, train loss 0.001922, train error 0.00,  test loss 5.992466, test error 56.00
# Epoch   900, train loss 0.001617, train error 0.00,  test loss 6.136746, test error 56.08
# Training model with  80 hidden variables
# Epoch     0, train loss 2.032291, train error 74.70,  test loss 1.991197, test error 75.40
# Epoch   100, train loss 0.236784, train error 3.85,  test loss 2.106087, test error 52.58
# Epoch   200, train loss 0.021477, train error 0.00,  test loss 3.464912, test error 53.33
# Epoch   300, train loss 0.008478, train error 0.00,  test loss 4.035396, test error 53.38
# Epoch   400, train loss 0.004972, train error 0.00,  test loss 4.380977, test error 53.40
# Epoch   500, train loss 0.003415, train error 0.00,  test loss 4.622274, test error 53.50
# Epoch   600, train loss 0.002564, train error 0.00,  test loss 4.808884, test error 53.42
# Epoch   700, train loss 0.002030, train error 0.00,  test loss 4.961968, test error 53.38
# Epoch   800, train loss 0.001668, train error 0.00,  test loss 5.088045, test error 53.25
# Epoch   900, train loss 0.001409, train error 0.00,  test loss 5.199341, test error 53.38
# Training model with  90 hidden variables
# Epoch     0, train loss 1.994350, train error 74.25,  test loss 1.919045, test error 75.18
# Epoch   100, train loss 0.128525, train error 0.78,  test loss 2.225291, test error 52.62
# Epoch   200, train loss 0.014857, train error 0.00,  test loss 3.284742, test error 53.47
# Epoch   300, train loss 0.006494, train error 0.00,  test loss 3.707676, test error 53.55
# Epoch   400, train loss 0.003986, train error 0.00,  test loss 3.975384, test error 53.62
# Epoch   500, train loss 0.002809, train error 0.00,  test loss 4.163371, test error 53.55
# Epoch   600, train loss 0.002133, train error 0.00,  test loss 4.312968, test error 53.60
# Epoch   700, train loss 0.001706, train error 0.00,  test loss 4.434812, test error 53.53
# Epoch   800, train loss 0.001413, train error 0.00,  test loss 4.537395, test error 53.58
# Epoch   900, train loss 0.001200, train error 0.00,  test loss 4.627121, test error 53.55
# Training model with 100 hidden variables
# Epoch     0, train loss 2.006520, train error 75.95,  test loss 1.950897, test error 75.72
# Epoch   100, train loss 0.092765, train error 0.25,  test loss 2.147032, test error 50.00
# Epoch   200, train loss 0.012330, train error 0.00,  test loss 2.995318, test error 51.03
# Epoch   300, train loss 0.005748, train error 0.00,  test loss 3.346408, test error 51.03
# Epoch   400, train loss 0.003586, train error 0.00,  test loss 3.564246, test error 50.92
# Epoch   500, train loss 0.002551, train error 0.00,  test loss 3.727375, test error 50.88
# Epoch   600, train loss 0.001953, train error 0.00,  test loss 3.853342, test error 50.97
# Epoch   700, train loss 0.001569, train error 0.00,  test loss 3.956347, test error 50.95
# Epoch   800, train loss 0.001302, train error 0.00,  test loss 4.044312, test error 50.83
# Epoch   900, train loss 0.001108, train error 0.00,  test loss 4.119572, test error 50.70
# Training model with 120 hidden variables
# Epoch     0, train loss 1.971422, train error 73.50,  test loss 1.907587, test error 72.82
# Epoch   100, train loss 0.049118, train error 0.00,  test loss 2.170330, test error 49.83
# Epoch   200, train loss 0.009429, train error 0.00,  test loss 2.751250, test error 49.83
# Epoch   300, train loss 0.004706, train error 0.00,  test loss 3.018341, test error 50.05
# Epoch   400, train loss 0.003007, train error 0.00,  test loss 3.191520, test error 49.92
# Epoch   500, train loss 0.002169, train error 0.00,  test loss 3.319939, test error 49.92
# Epoch   600, train loss 0.001676, train error 0.00,  test loss 3.420387, test error 49.78
# Epoch   700, train loss 0.001354, train error 0.00,  test loss 3.503559, test error 49.85
# Epoch   800, train loss 0.001130, train error 0.00,  test loss 3.574606, test error 49.83
# Epoch   900, train loss 0.000966, train error 0.00,  test loss 3.636758, test error 49.83
# Training model with 140 hidden variables
# Epoch     0, train loss 1.973122, train error 73.10,  test loss 1.899940, test error 72.72
# Epoch   100, train loss 0.035755, train error 0.00,  test loss 2.204129, test error 49.83
# Epoch   200, train loss 0.008065, train error 0.00,  test loss 2.708982, test error 50.38
# Epoch   300, train loss 0.004137, train error 0.00,  test loss 2.944389, test error 50.05
# Epoch   400, train loss 0.002693, train error 0.00,  test loss 3.101272, test error 50.22
# Epoch   500, train loss 0.001959, train error 0.00,  test loss 3.217410, test error 50.25
# Epoch   600, train loss 0.001524, train error 0.00,  test loss 3.311198, test error 50.22
# Epoch   700, train loss 0.001237, train error 0.00,  test loss 3.387430, test error 50.47
# Epoch   800, train loss 0.001036, train error 0.00,  test loss 3.453238, test error 50.38
# Epoch   900, train loss 0.000888, train error 0.00,  test loss 3.510220, test error 50.45
# Training model with 160 hidden variables
# Epoch     0, train loss 1.922214, train error 70.68,  test loss 1.851927, test error 72.55
# Epoch   100, train loss 0.027686, train error 0.00,  test loss 2.083920, test error 48.40
# Epoch   200, train loss 0.007048, train error 0.00,  test loss 2.476133, test error 48.62
# Epoch   300, train loss 0.003710, train error 0.00,  test loss 2.670965, test error 48.47
# Epoch   400, train loss 0.002441, train error 0.00,  test loss 2.800787, test error 48.38
# Epoch   500, train loss 0.001788, train error 0.00,  test loss 2.897211, test error 48.15
# Epoch   600, train loss 0.001397, train error 0.00,  test loss 2.974576, test error 48.00
# Epoch   700, train loss 0.001139, train error 0.00,  test loss 3.037828, test error 47.97
# Epoch   800, train loss 0.000956, train error 0.00,  test loss 3.093288, test error 48.12
# Epoch   900, train loss 0.000821, train error 0.00,  test loss 3.141196, test error 48.15
# Training model with 180 hidden variables
# Epoch     0, train loss 1.932081, train error 72.00,  test loss 1.853039, test error 72.28
# Epoch   100, train loss 0.023841, train error 0.00,  test loss 2.139869, test error 49.47
# Epoch   200, train loss 0.006498, train error 0.00,  test loss 2.502413, test error 49.12
# Epoch   300, train loss 0.003485, train error 0.00,  test loss 2.682531, test error 49.03
# Epoch   400, train loss 0.002310, train error 0.00,  test loss 2.802049, test error 49.05
# Epoch   500, train loss 0.001700, train error 0.00,  test loss 2.894245, test error 49.12
# Epoch   600, train loss 0.001333, train error 0.00,  test loss 2.966659, test error 49.05
# Epoch   700, train loss 0.001088, train error 0.00,  test loss 3.027756, test error 48.97
# Epoch   800, train loss 0.000916, train error 0.00,  test loss 3.079842, test error 49.00
# Epoch   900, train loss 0.000787, train error 0.00,  test loss 3.125365, test error 48.97
# Training model with 200 hidden variables
# Epoch     0, train loss 1.908570, train error 69.43,  test loss 1.836618, test error 71.22
# Epoch   100, train loss 0.022070, train error 0.00,  test loss 2.036649, test error 48.05
# Epoch   200, train loss 0.006250, train error 0.00,  test loss 2.360440, test error 48.20
# Epoch   300, train loss 0.003386, train error 0.00,  test loss 2.525596, test error 48.25
# Epoch   400, train loss 0.002248, train error 0.00,  test loss 2.633342, test error 48.17
# Epoch   500, train loss 0.001660, train error 0.00,  test loss 2.716897, test error 48.10
# Epoch   600, train loss 0.001303, train error 0.00,  test loss 2.783815, test error 48.22
# Epoch   700, train loss 0.001065, train error 0.00,  test loss 2.839698, test error 48.28
# Epoch   800, train loss 0.000896, train error 0.00,  test loss 2.887030, test error 48.28
# Epoch   900, train loss 0.000771, train error 0.00,  test loss 2.928638, test error 48.25
# Training model with 250 hidden variables
# Epoch     0, train loss 1.903368, train error 70.32,  test loss 1.854779, test error 71.97
# Epoch   100, train loss 0.017033, train error 0.00,  test loss 1.884090, test error 46.85
# Epoch   200, train loss 0.005344, train error 0.00,  test loss 2.133455, test error 46.53
# Epoch   300, train loss 0.002976, train error 0.00,  test loss 2.265396, test error 46.53
# Epoch   400, train loss 0.002006, train error 0.00,  test loss 2.356959, test error 46.60
# Epoch   500, train loss 0.001493, train error 0.00,  test loss 2.425448, test error 46.42
# Epoch   600, train loss 0.001178, train error 0.00,  test loss 2.480514, test error 46.42
# Epoch   700, train loss 0.000967, train error 0.00,  test loss 2.527053, test error 46.42
# Epoch   800, train loss 0.000817, train error 0.00,  test loss 2.567492, test error 46.42
# Epoch   900, train loss 0.000704, train error 0.00,  test loss 2.602148, test error 46.35
# Training model with 300 hidden variables
# Epoch     0, train loss 1.878536, train error 68.40,  test loss 1.815818, test error 69.88
# Epoch   100, train loss 0.014154, train error 0.00,  test loss 1.854290, test error 47.03
# Epoch   200, train loss 0.004760, train error 0.00,  test loss 2.070520, test error 47.00
# Epoch   300, train loss 0.002700, train error 0.00,  test loss 2.187928, test error 46.97
# Epoch   400, train loss 0.001842, train error 0.00,  test loss 2.270510, test error 47.00
# Epoch   500, train loss 0.001380, train error 0.00,  test loss 2.332191, test error 47.05
# Epoch   600, train loss 0.001094, train error 0.00,  test loss 2.381941, test error 47.08
# Epoch   700, train loss 0.000901, train error 0.00,  test loss 2.424161, test error 47.03
# Epoch   800, train loss 0.000763, train error 0.00,  test loss 2.460532, test error 47.03
# Epoch   900, train loss 0.000660, train error 0.00,  test loss 2.492346, test error 46.95
# Training model with 400 hidden variables
# Epoch     0, train loss 1.856794, train error 66.75,  test loss 1.798113, test error 68.15
# Epoch   100, train loss 0.011629, train error 0.00,  test loss 1.780514, test error 46.62
# Epoch   200, train loss 0.004151, train error 0.00,  test loss 1.960932, test error 46.55
# Epoch   300, train loss 0.002405, train error 0.00,  test loss 2.061385, test error 46.38
# Epoch   400, train loss 0.001657, train error 0.00,  test loss 2.131727, test error 46.38
# Epoch   500, train loss 0.001248, train error 0.00,  test loss 2.185102, test error 46.45
# Epoch   600, train loss 0.000994, train error 0.00,  test loss 2.228475, test error 46.38
# Epoch   700, train loss 0.000821, train error 0.00,  test loss 2.265102, test error 46.38
# Epoch   800, train loss 0.000697, train error 0.00,  test loss 2.296560, test error 46.42
# Epoch   900, train loss 0.000604, train error 0.00,  test loss 2.324266, test error 46.45

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
